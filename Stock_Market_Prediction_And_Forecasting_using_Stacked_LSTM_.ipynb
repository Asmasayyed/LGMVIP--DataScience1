# %% [markdown]
# LetsGrowMore #Nov 2022 Batch
#
# Name     : Sayyed Asma Fatima Ahmed Abbas
#
# Task 2   : Stock Market Prediction And Forecasting Using Stacked LSTM
#
# Dataset  : https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Reading The Dataset

# %%
data = pd.read_csv("https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv")

# %%
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %% [markdown]
# Data Sorting

# %%
data['Date']=pd.to_datetime(data['Date'])
print(type(data.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=data.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %% [markdown]
# 1. Visualization

# %%
plt.plot(df['Close'])

# %%
dff=df['Close']
dff
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# 2. Min Max Scalar

# %%
scaler=MinMaxScaler(feature_range=(0,1))
dff=scaler.fit_transform(np.array(dff).reshape(-1,1))
dff
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# 3.Splitting the Dataset

# %%
training_size=int(len(dff)*0.70)
test_size=len(dff)-training_size
train_data,test_data=dff[0:training_size,:],dff[training_size:len(dff),:1]

# %% [markdown]
# 4.Convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# 5.Splitting Data into Train and Test

# %%
time_step = 50
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1373, 50)
# (1373,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (560, 50)
# (560,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# 6.Creating the LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(25,return_sequences=True,input_shape=(50,1)))
model.add(LSTM(25,return_sequences=True))
model.add(LSTM(25))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 25)            2700
#
#  lstm_1 (LSTM)               (None, 50, 25)            5100
#
#  lstm_2 (LSTM)               (None, 25)                5100
#
#  dense (Dense)               (None, 1)                 26
#
# =================================================================
# Total params: 12,926
# Trainable params: 12,926
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=30,batch_size=64,verbose=1)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 10s 137ms/step - loss: 0.0121 - val_loss: 0.0019
# Epoch 2/30
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 3/30
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 4/30
# 20/20 [==============================] - 1s 68ms/step - loss: 9.7477e-04 - val_loss: 0.0013
# Epoch 5/30
# 20/20 [==============================] - 1s 68ms/step - loss: 9.5392e-04 - val_loss: 0.0013
# Epoch 6/30
# 20/20 [==============================] - 1s 67ms/step - loss: 9.1944e-04 - val_loss: 0.0012
# Epoch 7/30
# 20/20 [==============================] - 2s 86ms/step - loss: 9.1217e-04 - val_loss: 0.0013
# Epoch 8/30
# 20/20 [==============================] - 2s 78ms/step - loss: 8.9012e-04 - val_loss: 0.0012
# Epoch 9/30
# 20/20 [==============================] - 2s 91ms/step - loss: 8.7731e-04 - val_loss: 0.0011
# Epoch 10/30
# 20/20 [==============================] - 2s 95ms/step - loss: 8.3673e-04 - val_loss: 0.0011
# Epoch 11/30
# 20/20 [==============================] - 1s 67ms/step - loss: 8.1405e-04 - val_loss: 0.0011
# Epoch 12/30
# 20/20 [==============================] - 1s 68ms/step - loss: 7.9435e-04 - val_loss: 0.0010
# Epoch 13/30
# 20/20 [==============================] - 1s 67ms/step - loss: 7.8431e-04 - val_loss: 0.0010
# Epoch 14/30
# 20/20 [==============================] - 1s 67ms/step - loss: 7.8355e-04 - val_loss: 9.5056e-04
# Epoch 15/30
# 20/20 [==============================] - 1s 69ms/step - loss: 7.3216e-04 - val_loss: 9.1968e-04
# Epoch 16/30
# 20/20 [==============================] - 1s 68ms/step - loss: 7.0342e-04 - val_loss: 8.7131e-04
# Epoch 17/30
# 20/20 [==============================] - 1s 67ms/step - loss: 6.7888e-04 - val_loss: 8.3254e-04
# Epoch 18/30
# 20/20 [==============================] - 1s 67ms/step - loss: 6.8041e-04 - val_loss: 7.9526e-04
# Epoch 19/30
# 20/20 [==============================] - 1s 68ms/step - loss: 6.9720e-04 - val_loss: 8.0698e-04
# Epoch 20/30
# 20/20 [==============================] - 1s 68ms/step - loss: 6.5794e-04 - val_loss: 0.0010
# Epoch 21/30
# 20/20 [==============================] - 1s 67ms/step - loss: 6.8226e-04 - val_loss: 7.9085e-04
# Epoch 22/30
# 20/20 [==============================] - 1s 70ms/step - loss: 6.7477e-04 - val_loss: 7.5715e-04
# Epoch 23/30
# 20/20 [==============================] - 1s 70ms/step - loss: 6.0520e-04 - val_loss: 7.6575e-04
# Epoch 24/30
# 20/20 [==============================] - 1s 69ms/step - loss: 5.8047e-04 - val_loss: 6.6137e-04
# Epoch 25/30
# 20/20 [==============================] - 1s 68ms/step - loss: 5.5971e-04 - val_loss: 6.1551e-04
# Epoch 26/30
# 20/20 [==============================] - 1s 68ms/step - loss: 5.5859e-04 - val_loss: 8.3241e-04
# Epoch 27/30
# 20/20 [==============================] - 1s 68ms/step - loss: 6.0725e-04 - val_loss: 6.0472e-04
# Epoch 28/30
# 20/20 [==============================] - 1s 69ms/step - loss: 5.3987e-04 - val_loss: 5.6257e-04
# Epoch 29/30
# 20/20 [==============================] - 2s 95ms/step - loss: 5.1321e-04 - val_loss: 5.2547e-04
# Epoch 30/30
# 20/20 [==============================] - 1s 69ms/step - loss: 5.3184e-04 - val_loss: 5.3243e-04

# %% [markdown]
# 7.Prediction And Checking Performance

# %%
test_predict=model.predict(X_test)
# Out:
# 18/18 [==============================] - 2s 16ms/step

# %%
test_predicted=scaler.inverse_transform(test_predict)
test_predicted
# Out:
# array([[127.01993 ],
#        [127.0162  ],
#        [127.012665],
#        [127.11368 ],
#        [127.38884 ],
#        [127.95642 ],
#        [128.75403 ],
#        [129.68428 ],
#        [130.67273 ],
#        [131.5729  ],
#        [132.33434 ],
#        [132.9249  ],
#        [133.31422 ],
#        [133.53265 ],
#        [133.61389 ],
#        [133.49376 ],
#        [133.20161 ],
#        [132.93289 ],
#        [132.68019 ],
#        [132.44386 ],
#        [132.30365 ],
#        [132.18561 ],
#        [132.30603 ],
#        [132.78435 ],
#        [133.65741 ],
#        [134.78905 ],
#        [135.94151 ],
#        [136.8793  ],
#        [137.62196 ],
#        [138.20627 ],
#        [138.80191 ],
#        [139.452   ],
#        [139.92046 ],
#        [140.13423 ],
#        [140.0896  ],
#        [139.87909 ],
#        [139.55714 ],
#        [139.22719 ],
#        [139.0333  ],
#        [138.89207 ],
#        [138.82617 ],
#        [138.85286 ],
#        [138.96658 ],
#        [139.12262 ],
#        [139.25677 ],
#        [139.39442 ],
#        [139.53696 ],
#        [139.71326 ],
#        [139.93878 ],
#        [140.20686 ],
#        [140.51486 ],
#        [140.84113 ],
#        [141.06123 ],
#        [140.97229 ],
#        [140.66046 ],
#        [140.18466 ],
#        [139.73235 ],
#        [139.37971 ],
#        [139.07709 ],
#        [138.81737 ],
#        [138.6322  ],
#        [138.66183 ],
#        [138.8378  ],
#        [139.2632  ],
#        [139.98953 ],
#        [140.55559 ],
#        [140.9338  ],
#        [141.23022 ],
#        [141.45724 ],
#        [142.09251 ],
#        [143.08041 ],
#        [144.32574 ],
#        [145.70976 ],
#        [146.94342 ],
#        [148.13411 ],
#        [149.13171 ],
#        [149.9586  ],
#        [150.72813 ],
#        [151.35272 ],
#        [151.81769 ],
#        [152.19252 ],
#        [152.32043 ],
#        [152.00464 ],
#        [150.96355 ],
#        [149.40738 ],
#        [147.54317 ],
#        [145.55515 ],
#        [143.47256 ],
#        [141.28139 ],
#        [138.92326 ],
#        [136.56512 ],
#        [134.33401 ],
#        [132.13402 ],
#        [130.15628 ],
#        [128.2464  ],
#        [126.36837 ],
#        [124.724556],
#        [123.30045 ],
#        [122.160324],
#        [121.1612  ],
#        [120.32262 ],
#        [119.65768 ],
#        [119.07692 ],
#        [118.66679 ],
#        [118.51729 ],
#        [118.652504],
#        [119.08995 ],
#        [119.70084 ],
#        [120.37452 ],
#        [121.10295 ],
#        [121.83478 ],
#        [122.48635 ],
#        [123.070786],
#        [123.58193 ],
#        [123.99301 ],
#        [124.297516],
#        [124.47832 ],
#        [124.60384 ],
#        [124.696365],
#        [124.76668 ],
#        [124.713684],
#        [124.539276],
#        [124.19281 ],
#        [123.682816],
#        [122.99595 ],
#        [122.307655],
#        [121.66891 ],
#        [121.166504],
#        [120.85464 ],
#        [120.78236 ],
#        [120.95711 ],
#        [121.331665],
#        [121.865654],
#        [122.47655 ],
#        [123.10158 ],
#        [123.68153 ],
#        [124.290306],
#        [124.84039 ],
#        [125.40843 ],
#        [125.96955 ],
#        [126.49647 ],
#        [127.00408 ],
#        [127.54812 ],
#        [127.97204 ],
#        [128.28682 ],
#        [128.51906 ],
#        [128.6808  ],
#        [128.81567 ],
#        [128.98378 ],
#        [129.13582 ],
#        [129.3001  ],
#        [129.75333 ],
#        [130.67418 ],
#        [132.04497 ],
#        [133.68878 ],
#        [135.60576 ],
#        [137.57329 ],
#        [139.43091 ],
#        [140.98239 ],
#        [142.12321 ],
#        [142.74683 ],
#        [142.9478  ],
#        [142.82951 ],
#        [142.55501 ],
#        [142.221   ],
#        [141.8244  ],
#        [141.36716 ],
#        [140.86696 ],
#        [140.32489 ],
#        [139.99478 ],
#        [139.82571 ],
#        [139.87732 ],
#        [140.11726 ],
#        [140.47089 ],
#        [140.82321 ],
#        [141.09834 ],
#        [141.125   ],
#        [140.9949  ],
#        [140.82391 ],
#        [140.81955 ],
#        [141.02203 ],
#        [141.46994 ],
#        [142.08754 ],
#        [142.67903 ],
#        [143.50964 ],
#        [144.55153 ],
#        [145.61304 ],
#        [146.66704 ],
#        [147.6542  ],
#        [148.50531 ],
#        [149.20319 ],
#        [149.79651 ],
#        [150.32458 ],
#        [150.80653 ],
#        [151.1303  ],
#        [151.29587 ],
#        [151.42815 ],
#        [151.4911  ],
#        [151.43596 ],
#        [151.22884 ],
#        [150.84293 ],
#        [150.41182 ],
#        [150.08527 ],
#        [149.86826 ],
#        [149.7841  ],
#        [149.80602 ],
#        [149.99269 ],
#        [150.24698 ],
#        [150.56131 ],
#        [151.10258 ],
#        [151.78265 ],
#        [152.48651 ],
#        [153.0077  ],
#        [153.30937 ],
#        [153.46774 ],
#        [153.56018 ],
#        [153.58427 ],
#        [153.49704 ],
#        [153.39897 ],
#        [153.31648 ],
#        [153.1913  ],
#        [152.79005 ],
#        [152.20912 ],
#        [151.45811 ],
#        [150.48386 ],
#        [149.23679 ],
#        [147.87482 ],
#        [146.68854 ],
#        [145.72192 ],
#        [145.00453 ],
#        [144.68843 ],
#        [144.87714 ],
#        [145.60112 ],
#        [146.74072 ],
#        [148.04625 ],
#        [149.45673 ],
#        [150.81856 ],
#        [152.02286 ],
#        [152.90863 ],
#        [153.63864 ],
#        [154.33856 ],
#        [155.05199 ],
#        [155.71928 ],
#        [156.22125 ],
#        [156.5497  ],
#        [156.7128  ],
#        [156.64539 ],
#        [156.22003 ],
#        [155.32713 ],
#        [154.15268 ],
#        [152.83064 ],
#        [151.59166 ],
#        [150.5869  ],
#        [149.79933 ],
#        [149.48332 ],
#        [149.5081  ],
#        [149.96538 ],
#        [151.15173 ],
#        [153.08806 ],
#        [155.746   ],
#        [158.92645 ],
#        [162.2558  ],
#        [165.55315 ],
#        [168.43364 ],
#        [170.78455 ],
#        [172.35909 ],
#        [173.20967 ],
#        [173.3419  ],
#        [172.96075 ],
#        [172.29828 ],
#        [171.33095 ],
#        [170.21297 ],
#        [169.08983 ],
#        [167.9629  ],
#        [166.783   ],
#        [165.68373 ],
#        [164.72694 ],
#        [164.14034 ],
#        [163.72879 ],
#        [163.25604 ],
#        [162.41342 ],
#        [161.61786 ],
#        [161.67004 ],
#        [163.32869 ],
#        [166.27129 ],
#        [170.2166  ],
#        [174.74605 ],
#        [179.04443 ],
#        [183.02176 ],
#        [186.33887 ],
#        [188.80273 ],
#        [190.24101 ],
#        [191.0903  ],
#        [191.5694  ],
#        [191.77003 ],
#        [191.54031 ],
#        [191.12639 ],
#        [191.11055 ],
#        [191.51749 ],
#        [192.30208 ],
#        [193.43338 ],
#        [194.88812 ],
#        [196.2344  ],
#        [197.55977 ],
#        [198.70168 ],
#        [199.73703 ],
#        [200.78426 ],
#        [201.66333 ],
#        [202.24022 ],
#        [201.92624 ],
#        [200.58896 ],
#        [198.92957 ],
#        [196.94954 ],
#        [195.11499 ],
#        [193.7446  ],
#        [192.93266 ],
#        [192.55643 ],
#        [192.75296 ],
#        [193.41223 ],
#        [194.303   ],
#        [195.27507 ],
#        [196.26187 ],
#        [197.31804 ],
#        [198.28131 ],
#        [199.0493  ],
#        [199.63089 ],
#        [199.84692 ],
#        [199.61772 ],
#        [198.9616  ],
#        [198.36499 ],
#        [197.724   ],
#        [197.32173 ],
#        [197.74394 ],
#        [199.2322  ],
#        [201.51947 ],
#        [204.26456 ],
#        [207.01198 ],
#        [209.40477 ],
#        [211.77133 ],
#        [213.47958 ],
#        [214.42618 ],
#        [215.53741 ],
#        [216.62686 ],
#        [217.51602 ],
#        [218.80066 ],
#        [220.60286 ],
#        [222.74591 ],
#        [225.37039 ],
#        [228.95914 ],
#        [232.96896 ],
#        [236.93405 ],
#        [240.48218 ],
#        [243.55034 ],
#        [245.91614 ],
#        [248.05856 ],
#        [249.52385 ],
#        [250.66121 ],
#        [251.30473 ],
#        [251.27179 ],
#        [250.74344 ],
#        [249.63885 ],
#        [248.63344 ],
#        [248.07756 ],
#        [248.44664 ],
#        [248.99556 ],
#        [249.36897 ],
#        [249.4999  ],
#        [249.54266 ],
#        [249.73361 ],
#        [250.54582 ],
#        [251.8294  ],
#        [253.31703 ],
#        [254.92712 ],
#        [256.63635 ],
#        [258.25458 ],
#        [259.7042  ],
#        [261.3787  ],
#        [262.95438 ],
#        [264.21643 ],
#        [265.11624 ],
#        [265.71448 ],
#        [266.08066 ],
#        [266.4779  ],
#        [266.7818  ],
#        [266.923   ],
#        [266.8795  ],
#        [267.28763 ],
#        [267.92166 ],
#        [268.341   ],
#        [268.3779  ],
#        [267.71298 ],
#        [266.68497 ],
#        [265.5243  ],
#        [264.31247 ],
#        [263.03275 ],
#        [261.8025  ],
#        [260.59656 ],
#        [259.60742 ],
#        [258.22665 ],
#        [256.48724 ],
#        [253.9432  ],
#        [250.85904 ],
#        [247.31232 ],
#        [244.38188 ],
#        [242.2896  ],
#        [240.931   ],
#        [240.56874 ],
#        [240.85428 ],
#        [241.42294 ],
#        [241.9382  ],
#        [241.94237 ],
#        [241.24872 ],
#        [240.25558 ],
#        [238.95082 ],
#        [237.97409 ],
#        [237.56252 ],
#        [237.74083 ],
#        [238.38876 ],
#        [239.29079 ],
#        [240.32191 ],
#        [241.27042 ],
#        [241.78394 ],
#        [242.11356 ],
#        [242.05013 ],
#        [242.07529 ],
#        [242.33916 ],
#        [242.80913 ],
#        [243.45001 ],
#        [243.78888 ],
#        [243.20009 ],
#        [241.93668 ],
#        [240.34058 ],
#        [238.44655 ],
#        [236.43898 ],
#        [234.74612 ],
#        [233.56204 ],
#        [232.6246  ],
#        [232.85179 ],
#        [233.94887 ],
#        [235.36206 ],
#        [236.96109 ],
#        [238.52689 ],
#        [240.17772 ],
#        [241.66202 ],
#        [242.79498 ],
#        [243.5504  ],
#        [244.04436 ],
#        [244.53505 ],
#        [245.0892  ],
#        [245.8215  ],
#        [246.74667 ],
#        [247.74399 ],
#        [248.554   ],
#        [249.0932  ],
#        [249.66473 ],
#        [250.35193 ],
#        [251.12885 ],
#        [252.17711 ],
#        [253.11624 ],
#        [253.54393 ],
#        [253.55144 ],
#        [253.56369 ],
#        [253.40517 ],
#        [253.23471 ],
#        [252.74438 ],
#        [252.12885 ],
#        [249.89423 ],
#        [245.7658  ],
#        [240.37463 ],
#        [234.83397 ],
#        [229.60953 ],
#        [225.03745 ],
#        [221.53291 ],
#        [219.31349 ],
#        [218.50034 ],
#        [219.0247  ],
#        [220.68341 ],
#        [222.9036  ],
#        [225.67569 ],
#        [228.90578 ],
#        [231.93039 ],
#        [234.06363 ],
#        [235.69986 ],
#        [236.99606 ],
#        [238.05418 ],
#        [238.87251 ],
#        [239.2813  ],
#        [239.52623 ],
#        [239.75574 ],
#        [240.39922 ],
#        [241.0632  ],
#        [241.79846 ],
#        [242.08401 ],
#        [241.60556 ],
#        [240.38919 ],
#        [238.90407 ],
#        [237.51778 ],
#        [236.51968 ],
#        [235.84425 ],
#        [235.36867 ],
#        [235.33269 ],
#        [235.40059 ],
#        [236.35332 ],
#        [237.80646 ],
#        [239.1759  ],
#        [240.03052 ],
#        [240.81915 ],
#        [241.52573 ],
#        [241.87595 ],
#        [241.66309 ],
#        [240.68698 ],
#        [238.37163 ],
#        [235.38159 ],
#        [231.70656 ],
#        [227.51236 ],
#        [223.54349 ],
#        [220.38837 ],
#        [218.3439  ],
#        [216.86356 ],
#        [215.95956 ],
#        [215.71529 ],
#        [216.01112 ],
#        [216.94307 ],
#        [217.72821 ],
#        [218.22232 ],
#        [218.38483 ],
#        [218.54271 ],
#        [218.65498 ],
#        [218.67523 ],
#        [218.67537 ],
#        [218.47722 ],
#        [218.17104 ],
#        [217.97667 ],
#        [218.01773 ],
#        [218.45705 ],
#        [219.31244 ],
#        [220.18262 ],
#        [220.65834 ],
#        [220.47807 ],
#        [220.07538 ],
#        [219.40137 ],
#        [218.63997 ],
#        [217.97452 ],
#        [217.37402 ],
#        [216.99106 ],
#        [216.13335 ],
#        [214.7898  ],
#        [213.07602 ],
#        [211.31999 ],
#        [209.66876 ],
#        [207.93614 ],
#        [206.58664 ],
#        [206.30086 ],
#        [207.13272 ],
#        [208.72052 ],
#        [210.70819 ],
#        [212.76988 ],
#        [214.60194 ],
#        [216.21515 ],
#        [217.44473 ]], dtype=float32)

# %% [markdown]
# 8.Calculating Performance

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
performance = math.sqrt(mean_squared_error(ytest,test_predict))
performance
# Out:
# 0.0876527389483924

# %% [markdown]
# ##THANK YOU!!
# *HAPPY LEARNING ❤*
